# %%
def partition(a, low, high):
    pivot = a[high//2]      # last element is pivot
    i = low - 1          # index of smaller element

    for j in range(low, high):
        if a[j] <= pivot:
            i = i + 1
            a[i], a[j] = a[j], a[i]   # swap

    a[i + 1], a[high] = a[high], a[i + 1]
    return i + 1


def quicksort(a, low, high):
    if low < high:
        p = partition(a, low, high)
        quicksort(a, low, p - 1)
        quicksort(a, p + 1, high)


# Example
arr = [64, 34, 25, 5, 22, 11, 90, 12]
quicksort(arr, 0, len(arr) - 1)
print(arr)
# Out:
# [2, 3, 4, 5, 6, 9]

# %%
def quick_sort(arr):
    if len(arr) <= 1:
        return arr

    pivot = arr[-1]          # last element as pivot
    left = []
    right = []

    for i in range(len(arr) - 1):
        if arr[i] <= pivot:
            left.append(arr[i])
        else:
            right.append(arr[i])

    return quick_sort(left) + [pivot] + quick_sort(right)


# Example
arr = [10, 7, 8, 9, 1, 5]
sorted_arr = quick_sort(arr)
print(sorted_arr)
# Out:
# [1, 5, 7, 8, 9, 10]

# %%
def partition(a, low, high):
    mid = (low + high) // 2

    # move middle pivot to end
    a[mid], a[high] = a[high], a[mid]

    pivot = a[high]
    i = low - 1

    for j in range(low, high):
        if a[j] <= pivot:
            i += 1
            a[i], a[j] = a[j], a[i]

    a[i + 1], a[high] = a[high], a[i + 1]
    return i + 1
